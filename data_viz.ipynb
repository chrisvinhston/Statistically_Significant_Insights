# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
os.chdir(r'C:\Users\lilie\GitHubProjects\IronEstelle\Statistically_Significant_Insights\cleaned_data')
df = pd.read_csv('df_merged2.csv')

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Year', 'AvgCelsiusTemp', 'CO2', 'F-Gas', 'N2O',
#        'State'],
#       dtype='object')

# %%
df.State.value_counts()
# Out:
# EU        512
# Not EU    384
# Name: State, dtype: int64

# %%
df['G20'] = ['EU' if i=='EU'for i in df.State else i in df.Country for i in df.State]
df
# Out:
#   File "<ipython-input-25-db2dfa33678a>", line 1
#     df['G20'] = ['EU' if i=='EU'for i in df.State else i in df.Country for i in df.State]
#                                 ^
# SyntaxError: invalid syntax

# %%
fig=plt.figure(figsize=(25,15))
sns.lineplot(data=df, x="Year", y="AvgCelsiusTemp",hue='State')
