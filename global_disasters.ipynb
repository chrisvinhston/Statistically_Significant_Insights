# %%
import pandas as pd
import requests as r
from bs4 import BeautifulSoup
import numpy as np

import os

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_natural_disasters_by_death_toll#Ten_deadliest_natural_disasters_since_1900_excluding_epidemics_and_famines")

# %%
t0 = pd.DataFrame(tables[0])
t0['Year'] = t0['Date']
t0.rename(columns = {'Death toll (Highest estimate)':'Death toll (estimate)'}, inplace = True)

# %%
t1 = pd.DataFrame(tables[1])
t1['Year'] = t1['Date']
t1.rename(columns = {'Event*':'Event'}, inplace = True)

# %%
t2 = pd.DataFrame(tables[2])
t2['Rank'] = np.nan
t2.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t2 = tables[2][['Rank','Death toll (estimate)', 'Event', 'Location', 'Type', 'Date', 'Year']]

# %%
t3 = pd.DataFrame(tables[3])
t3['Rank'] = np.nan
t3.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t3 = t3[['Rank','Death toll (estimate)', 'Event', 'Location', 'Type', 'Date', 'Year']]
t3
# Out:
#     Rank Death toll (estimate)                                     Event  \
# 0    NaN                 20085                   2001 Gujarat earthquake
# 1    NaN                  1030                     2002 Indian heat wave
# 2    NaN                 70000                   2003 European heat wave
# 3    NaN                227898  2004 Indian Ocean earthquake and tsunami
# 4    NaN                 87351                   2005 Kashmir earthquake
# 5    NaN                  5782                2006 Yogyakarta earthquake
# 6    NaN                 15000                              Cyclone Sidr
# 7    NaN                138373                            Cyclone Nargis
# 8    NaN                  1115                   2009 Sumatra earthquake
# 9    NaN         100000-316000                     2010 Haiti earthquake
# 10   NaN                 19749        2011 Tōhoku earthquake and tsunami
# 11   NaN                  1901                             Typhoon Bopha
# ...

# %%
t4 = pd.DataFrame(tables[4])
t4['Year'] = t4['Date']
t4['Type'] ='Earthquake'
t4
# Out:
#     Rank Death toll (estimate)                         Event  \
# 0    1.0                830000       1556 Shaanxi earthquake
# 1    2.0   242,769–655,000[13]      1976 Tangshan earthquake
# 2    3.0       100,000−316,000         2010 Haiti earthquake
# 3    4.0            273,400[9]       1920 Haiyuan earthquake
# 4    5.0    250,000–300,000[7]        526 Antioch earthquake
# 5    6.0           260,000[14]        115 Antioch earthquake
# 6    7.0                230000        1138 Aleppo earthquake
# 7    8.0                227898  2004 Indian Ocean earthquake
# 8    9.0                200000  1303 Hongdong earthquake[15]
# 9    9.0                200000        856 Damghan earthquake
# 10   9.0                200000        1780 Tabriz earthquake
#
#                                   Location                Date  \
# 0                 Ming dynasty (now China)    January 23, 1556
# 1                                    China       July 28, 1976
# ...

# %%
t5 = pd.DataFrame(tables[5])
t5.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t5['Year'] = t5['Date']
t5 = t5[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t5['Type'] ='Famine'
t5
# Out:
#    Rank     Death toll (estimate)  \
# 0   1.0     15,000,000–55,000,000
# 1   2.0            25,000,000[16]
# 2   3.0  9,000,000–13,000,000[17]
# 3   4.0                  11000000
# 4   4.0                  11000000
# 5   6.0                  10000000
# 6   7.0                   7500000
# 7   8.0                   7400000
# 8   9.0       5,000,000–8,000,000
# 9  10.0                   5500000
#
#                                                Event                 Location  \
# 0                               Great Chinese Famine                    China
# 1                             Chinese famine of 1907                    China
# 2               Northern Chinese Famine of 1876–1879                    China
# 3                                     Chalisa famine                    India
# 4                   Doji bara famine or Skull famine                    India
# 5  Great Bengal famine of 1770, incl. Bihar & Orissa            British India
# ...

# %%
# !! dont use as data is not sufficiant. 
tables[6]
# Out:
#     Rank Death toll (unofficial)  \
# 0    1.0                 10,000+
# 1    2.0                  "Tens"
# 2    3.0                     10+
# 3    4.0                       2
# 4    4.0                       2
# 5    6.0                       1
# 6    6.0                       1
# 7    6.0                       1
# 8    6.0                       1
# 9    6.0                       1
# 10   6.0                       1
# 11   6.0                       1
# 12   6.0                       1
#
#                                              Location          Date  \
# 0                              Qingyang, Gansu, China          1490
# 1                Changshou District, Chongqing, China          1639
# 2                                               China        616 CE
# 3                          Malacca ship, Indian Ocean          1648
# 4   Podkamennaya Tunguska River, Siberia, Russian ...          1908
# 5                            Cremona, Lombardy, Italy          1511
# ...

# %%
t7 = pd.DataFrame(tables[7])
t7.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t7['Year'] = t7['Date']
t7 = t7[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t7['Type'] ='Limnic Eruptions'

# %%
t8 = pd.DataFrame(tables[8])
t8.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t8['Year'] = t8['Date']
t8 = t8[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t8['Type'] ='Wildfires/Bushfires'
t8
# Out:
#    Rank Death toll (estimate)                                 Event  \
# 0   1.0           1,200–2,500                         Peshtigo Fire
# 1   2.0                  1200                         Kursha-2 Fire
# 2   3.0                   453                      Cloquet Fire[24]
# 3   4.0                  418+                   Great Hinckley Fire
# 4   5.0                   282                            Thumb Fire
# 5   6.0                   240  1997 Indonesian forest fires[25][26]
# 6   7.0                   223                         Matheson Fire
# 7   8.0                   191             Black Dragon Fire[25][26]
# 8   9.0                   173      Black Saturday bushfires[25][26]
# 9  10.0               160–300                        Miramichi Fire
#
#                             Location               Date               Year  \
# 0           Wisconsin, United States    October 8, 1871    October 8, 1871
# ...

# %%
t9 = pd.DataFrame(tables[9])
t9['Year'] = t9['Date']
t9['Type'] ='Avalanches/Landslides'
t9
# Out:
#    Rank Death toll (estimate)  \
# 0   1.0                100000
# 1   1.0                100000
# 2   3.0                 22000
# 3   4.0         10,000–30,000
# 4   4.0                 10000
# 5   6.0          5,000–28,000
# 6   7.0           4,000–6,000
# 7   7.0                  4000
# 8   9.0                  3466
# 9  10.0                  3429
#
#                                                Event    Location  Date  Year  \
# 0  1786 Dadu River landslide dam; triggered by th...       China  1786  1786
# 1  1920 Haiyuan landslides; triggered by the 1920...       China  1920  1920
# 2  1970 Huascarán avalanche; triggered by the 197...        Peru  1970  1970
# 3                                 Vargas tragedy[29]   Venezuela  1999  1999
# 4                    White Friday avalanches[30][31]       Italy  1916  1916
# 5                            Khait landslide[32][33]  Tajikistan  1949  1949
# 6                          1941 Huaraz avalanche[34]        Peru  1941  1941
# ...

# %%
t10 = pd.DataFrame(tables[10])
t10['Year'] = t10['Date']
t10['Type'] ='Blizzard'
t10
# Out:
#    Rank  Death toll (estimate)                            Event  \
# 0   1.0                   4000               1972 Iran blizzard
# 1   2.0                   3000             Carolean Death March
# 2   3.0                    926        2008 Afghanistan blizzard
# 3   4.0                    400           Great Blizzard of 1888
# 4   5.0                    353  Great Appalachian Storm of 1950
# 5   6.0                    318        1993 Storm of the Century
# 6   7.0                    286         December 1960 nor'easter
# 7   8.0                    250        Great Lakes Storm of 1913
# 8   9.0                    235             Schoolhouse Blizzard
# 9  10.0                    201  North American blizzard of 1966
#
#                                         Location  Date  Year      Type
# 0                                           Iran  1972  1972  Blizzard
# 1                                         Norway  1719  1719  Blizzard
# ...

# %%
t11 = pd.DataFrame(tables[11])
t11.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t11['Year'] = t11['Date']
t11 = t11[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t11['Type'] ='Flood'
t11
# Out:
#    Rank     Death toll (estimate)                               Event  \
# 0   1.0     400,000–4,000,000[35]                   1931 China floods
# 1   2.0         900,000–2,000,000  1887 Yellow River (Huang He) flood
# 2   3.0               230,000[36]            1975 Banqiao Dam failure
# 3   4.0                    145000                  1935 Yangtze flood
# 4   5.0                  100,000+      St. Felix's flood, storm surge
# 5   6.0                    100000     Hanoi and Red River Delta flood
# 6   7.0  100,000[citation needed]            1911 Yangtze River flood
# 7   8.0   100,000[37][38][39][40]                   The flood of 1099
# 8   9.0         50,000–80,000[38]      St. Lucia's flood, storm surge
# 9  10.0                     60000        North Sea flood, storm surge
#
#                 Location  Date  Year   Type
# 0                  China  1931  1931  Flood
# 1                  China  1887  1887  Flood
# 2                  China  1975  1975  Flood
# ...

# %%
t12 = pd.DataFrame(tables[12])
t12.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t12['Year'] = t12['Date']
t12 = t12[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t12['Type'] ='Heat Wave'
t12
# Out:
#    Rank Death toll (estimate)                                 Event  \
# 0   1.0                 70000               2003 European heat wave
# 1   2.0                 56000                2010 Russian heat wave
# 2   3.0                  9500  1901 eastern United States heat wave
# 3   4.0          5,000–10,000          1988 United States heat wave
# 4   5.0                  3418               2006 European heat wave
# 5   6.0                  2541                  1998 India heat wave
# 6   7.0                  2500                 2015 Indian heat wave
# 7   8.0                  2000               2015 Pakistan heat wave
# 8   9.0           1,700–5,000          1980 United States heat wave
# 9  10.0             1,718[42]               2010 Japanese heat wave
#
#         Location      Date      Year       Type
# 0         Europe      2003      2003  Heat Wave
# 1         Russia      2010      2010  Heat Wave
# 2  United States      1901      1901  Heat Wave
# ...

# %%
# Pandemics / Epidemics
t13 = pd.DataFrame(tables[13])
t13['Year'] = t13['Date']
t13['Type'] ='Pandemics / Epidemics'
t13
# Out:
#    Rank                              Death toll (estimate)  \
# 0   1.0                                 75–200 million[43]
# 1   2.0               50 million+ (17–100 million)[44][45]
# 2   3.0                       35 million+ (as of 2018)[46]
# 3   4.0                          30–50 million[47][48][49]
# 4   5.0                  12 million+ (India and China)[50]
# 5   6.0                       5–15 million[51][52][53][54]
# 6   7.0                                   5–10 million[55]
# 7   8.0                                    5–8 million[53]
# 8   9.0  3.4 million+ (reported)[56]– 7.2 million (esti...
# 9  10.0                                    2.5 million[58]
#
#                               Event                       Location  \
# 0                       Black Death  Europe, Asia and North Africa
# 1                 1918 flu pandemic                      Worldwide
# 2                 HIV/AIDS pandemic                      Worldwide
# ...

# %%
#Tornadoes
t14 = pd.DataFrame(tables[14])
t14.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t14['Year'] = t14['Date']
t14 = t14[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t14['Type'] ='Tornadoes'
t14
# Out:
#    Rank  Death toll (estimate)                          Event  \
# 0   1.0                   1300  The Daulatpur–Saturia tornado
# 1   2.0                    695          The Tri-State Tornado
# 2   3.0                    681             1973 Dhaka tornado
# 3   4.0                    660     1969 East Pakistan tornado
# 4   5.0                    600    The Valletta, Malta tornado
# 5   6.0                    500           The Sicily Tornadoes
# 6   6.0                    500          Narail-Magura tornado
# 7   6.0                    500     Madaripur-Shibchar tornado
# 8   9.0                    400  The Ivanovo-Yaroslavl tornado
# 9  10.0                    317      The Great Natchez Tornado
#
#                                             Location          Date  \
# 0                              Manikganj, Bangladesh          1989
# 1          United States (Missouri–Illinois–Indiana)          1925
# 2                                         Bangladesh          1973
# ...

# %%
#Tropical Cyclones
t15 = pd.DataFrame(tables[15])
t15.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t15['Year'] = t15['Date']
t15 = t15[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t15['Type'] ='Tropical Cyclones'
t15
# Out:
#    Rank         Death toll (estimate)  \
# 0   1.0                      500,000+
# 1   2.0                        300000
# 2   2.0                        300000
# 3   4.0                        229000
# 4   5.0                   200,000[60]
# 5   6.0  150,000 (30,000–300,000)[61]
# 6   7.0                        138866
# 7   8.0                        138373
# 8   9.0                        100000
# 9  10.0                 10,000–50,000
#
#                                                Event  \
# 0                                 1970 Bhola cyclone
# 1    1737 Calcutta cyclone[59][better source needed]
# 2                              1839 India Cyclone[8]
# 3  Super Typhoon Nina—contributed to Banqiao Dam ...
# 4                   Great Backerganj Cyclone of 1876
# 5                              1881 Haiphong typhoon
# 6                            1991 Bangladesh cyclone
# 7                                     Cyclone Nargis
# 8                              July 1780 typhoon[62]
# ...

# %%
#Tsunamis
t16 = pd.DataFrame(tables[16])
t16.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t16['Year'] = t16['Date']
t16 = t16[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t16['Type'] ='Tsunamis'
t16
# Out:
#    Rank Death toll (estimate)                      Event      Location  \
# 0   1.0                227898  2004 Indian Ocean tsunami  Indian Ocean
# 1   2.0            123,000[1]    1908 Messina earthquake         Italy
# 2   3.0        36,417–120,000  1883 eruption of Krakatoa     Indonesia
# 3   4.0     40,000–50,000[64]     1755 Lisbon earthquake      Portugal
# 4   5.0        30,000–100,000            Minoan eruption        Greece
# 5   6.0                 31000     1498 Nankai earthquake         Japan
# 6   7.0                 30000       1707 Hōei earthquake         Japan
# 7   8.0            27,122[65]    1896 Sanriku earthquake         Japan
# 8   9.0                 25674      1868 Arica earthquake         Chile
# 9  10.0  5,700[66]–50,000[67]       365 Crete earthquake        Greece
#
#                  Date                Year      Type
# 0   December 26, 2004   December 26, 2004  Tsunamis
# 1   December 28, 1908   December 28, 1908  Tsunamis
# ...

# %%
#Volcanic Eruptions
t17 = pd.DataFrame(tables[17])
t17.rename(columns = {'Death toll':'Death toll (estimate)'}, inplace = True)
t17['Year'] = t17['Date']
t17 = t17[['Rank','Death toll (estimate)', 'Event', 'Location', 'Date', 'Year']]
t17['Type'] ='Volcanic Eruptions'
t17
# Out:
#    Rank Death toll (estimate)  \
# 0   1.0           71,000+[68]
# 1   2.0           36,000+[69]
# 2   3.0            30,000[70]
# 3   4.0            23,000[71]
# 4   5.0            15,000[72]
# 5   6.0            13,000[73]
# 6   7.0               10,000+
# 7   8.0             6,000[74]
# 8   9.0             5,000[75]
# 9  10.0             4,011[76]
#
#                                                Event    Location  \
# 0  1815 eruption of Mount Tambora (see also Year ...   Indonesia
# 1                          1883 eruption of Krakatoa   Indonesia
# 2                       1902 eruption of Mount Pelée  Martinique
# 3                                     Armero tragedy    Colombia
# 4                  1792 Unzen earthquake and tsunami       Japan
# 5                Eruption of Mount Vesuvius in 79 AD       Italy
# 6                                1586 Kelud eruption   Indonesia
# 7                          1902 Santa Maria eruption   Guatemala
# ...

# %%
dirty_df = pd.concat([t0, t1, t2, t3, t4, t5, t7, t8, t9, t10, t11, t12, t13, t14, t15, t16, t17], axis=0)

# %%
dirty_df.shape
# Out:
# (226, 7)

# %%
dirty_df.to_csv('.\org_global_disasters.csv', index=False)

# %%
df = dirty_df.copy()

# %%
df.isna().sum()
# Out:
# Rank                     83
# Death toll (estimate)     0
# Event                     0
# Location                  2
# Date                      1
# Year                      0
# Type                     20
# dtype: int64

# %%
df.Year = df.Year.str[-4:]

# %%
df['Death toll (estimate)'].dtype
# Out:
# dtype('O')

# %%
df['Death toll (estimate)'] = df['Death toll (estimate)'].str.replace('([])',' ')
# Out:
# <ipython-input-119-9e6e234feb30>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Death toll (estimate)'] = df['Death toll (estimate)'].str.replace('([])',' ')
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-119-9e6e234feb30> in <module>
# ----> 1 df['Death toll (estimate)'] = df['Death toll (estimate)'].str.replace('([])',' ')
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in replace(self, pat, repl, n, case, flags, regex)
#    1309                 warnings.warn(msg, FutureWarning, stacklevel=3)
# ...

# %%
df['Death toll (estimate)']
# Out:
# 0    4,000,000[1][nb 1]
# 1    2,000,000[2][3][4]
# 2            830,000[5]
# 3                655000
# 4           500,000+[1]
#             ...
# 5            13,000[73]
# 6               10,000+
# 7             6,000[74]
# 8             5,000[75]
# 9             4,011[76]
# Name: Death toll (estimate), Length: 226, dtype: object
